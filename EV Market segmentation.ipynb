# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv(r"C:\Users\Tharun\Downloads\car details v4.csv")
data
# Out:
#                Make                                  Model    Price  Year  \
# 0             Honda                    Amaze 1.2 VX i-VTEC   505000  2017
# 1     Maruti Suzuki                        Swift DZire VDI   450000  2014
# 2           Hyundai                   i10 Magna 1.2 Kappa2   220000  2011
# 3            Toyota                               Glanza G   799000  2019
# 4            Toyota        Innova 2.4 VX 7 STR [2016-2020]  1950000  2018
# ...             ...                                    ...      ...   ...
# 2054       Mahindra                  XUV500 W8 [2015-2017]   850000  2016
# 2055        Hyundai                           Eon D-Lite +   275000  2014
# 2056           Ford            Figo Duratec Petrol ZXI 1.2   240000  2013
# 2057            BMW  5-Series 520d Luxury Line [2017-2019]  4290000  2018
# 2058       Mahindra      Bolero Power Plus ZLX [2016-2019]   670000  2017
#
#       Kilometer Fuel Type Transmission    Location   Color   Owner  \
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2059 entries, 0 to 2058
# Data columns (total 20 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Make                2059 non-null   object
#  1   Model               2059 non-null   object
#  2   Price               2059 non-null   int64
#  3   Year                2059 non-null   int64
#  4   Kilometer           2059 non-null   int64
#  5   Fuel Type           2059 non-null   object
#  6   Transmission        2059 non-null   object
#  7   Location            2059 non-null   object
#  8   Color               2059 non-null   object
#  9   Owner               2059 non-null   object
#  10  Seller Type         2059 non-null   object
#  11  Engine              1979 non-null   object
#  12  Max Power           1979 non-null   object
#  13  Max Torque          1979 non-null   object
#  14  Drivetrain          1923 non-null   object
# ...

# %%
data.isnull().sum()
# Out:
# Make                    0
# Model                   0
# Price                   0
# Year                    0
# Kilometer               0
# Fuel Type               0
# Transmission            0
# Location                0
# Color                   0
# Owner                   0
# Seller Type             0
# Engine                 80
# Max Power              80
# Max Torque             80
# Drivetrain            136
# Length                 64
# Width                  64
# Height                 64
# Seating Capacity       64
# Fuel Tank Capacity    113
# dtype: int64

# %%
df = data.dropna()

# %%
df
# Out:
#                Make                                  Model    Price  Year  \
# 0             Honda                    Amaze 1.2 VX i-VTEC   505000  2017
# 1     Maruti Suzuki                        Swift DZire VDI   450000  2014
# 2           Hyundai                   i10 Magna 1.2 Kappa2   220000  2011
# 3            Toyota                               Glanza G   799000  2019
# 4            Toyota        Innova 2.4 VX 7 STR [2016-2020]  1950000  2018
# ...             ...                                    ...      ...   ...
# 2053  Maruti Suzuki                   Ritz Vxi (ABS) BS-IV   245000  2014
# 2054       Mahindra                  XUV500 W8 [2015-2017]   850000  2016
# 2055        Hyundai                           Eon D-Lite +   275000  2014
# 2056           Ford            Figo Duratec Petrol ZXI 1.2   240000  2013
# 2057            BMW  5-Series 520d Luxury Line [2017-2019]  4290000  2018
#
#       Kilometer Fuel Type Transmission    Location   Color   Owner  \
# ...

# %%
df = df.drop(['Max Power','Max Torque'], axis=1)

# %%
df.describe()
# Out:
#               Price         Year     Kilometer       Length        Width  \
# count  1.874000e+03  1874.000000  1.874000e+03  1874.000000  1874.000000
# mean   1.718279e+06  2016.713447  5.317814e+04  4281.512807  1767.886339
# std    2.426090e+06     3.138477  5.878833e+04   436.220747   131.344883
# min    4.900000e+04  1988.000000  0.000000e+00  3099.000000  1475.000000
# 25%    5.000000e+05  2015.000000  2.801975e+04  3985.000000  1695.000000
# 50%    8.424995e+05  2017.000000  4.879750e+04  4360.000000  1770.000000
# 75%    1.908250e+06  2019.000000  7.100000e+04  4620.000000  1831.000000
# max    3.500000e+07  2022.000000  2.000000e+06  5569.000000  2220.000000
#
#             Height  Seating Capacity  Fuel Tank Capacity
# count  1874.000000       1874.000000         1874.000000
# mean   1588.967983          5.295091           52.217343
# std     134.627659          0.807008           15.167250
# min    1213.000000          2.000000           15.000000
# ...

# %%
df.columns
# Out:
# Index(['Make', 'Price', 'Year', 'Kilometer', 'Fuel Type', 'Transmission',
#        'Location', 'Color', 'Owner', 'Seller Type', 'Engine', 'Drivetrain',
#        'Length', 'Width', 'Height', 'Seating Capacity', 'Fuel Tank Capacity'],
#       dtype='object')

# %%
# Categorical Encoding
df['Make'] = df['Make'].astype('category')
df['Price'] = df['Price'].astype('category')
df['Year'] = df['Year'].astype('category')
df['Kilometer'] = df['Kilometer'].astype('category')
df['Fuel Type'] = df['Fuel Type'].astype('category')
df['Transmission'] = df['Transmission'].astype('category')
df['Location'] = df['Location'].astype('category')
df['Color'] = df['Color'].astype('category')
df['Owner'] = df['Owner'].astype('category')
df['Seller Type'] = df['Seller Type'].astype('category')
df['Engine'] = df['Engine'].astype('category')
df['Drivetrain'] = df['Drivetrain'].astype('category')
df['Length'] = df['Length'].astype('category')
df['Width'] = df['Width'].astype('category')
df['Height'] = df['Height'].astype('category')
df['Seating Capacity'] = df['Seating Capacity'].astype('category')
df['Fuel Tank Capacity'] = df['Fuel Tank Capacity'].astype('category')

# %%
df['Make'] = df['Make'].cat.codes
df['Price'] = df['Price'].cat.codes
df['Year'] = df['Year'].cat.codes
df['Kilometer'] = df['Kilometer'].cat.codes
df['Fuel Type'] = df['Fuel Type'].cat.codes
df['Transmission'] = df['Transmission'].cat.codes
df['Location'] = df['Location'].cat.codes
df['Color'] = df['Color'].cat.codes
df['Owner'] = df['Owner'].cat.codes
df['Seller Type'] = df['Seller Type'].cat.codes
df['Engine'] = df['Engine'].cat.codes
df['Drivetrain'] = df['Drivetrain'].cat.codes
df['Length'] = df['Length'].cat.codes
df['Width'] = df['Width'].cat.codes
df['Height'] = df['Height'].cat.codes
df['Seating Capacity'] = df['Seating Capacity'].cat.codes
df['Fuel Tank Capacity'] = df['Fuel Tank Capacity'].cat.codes

# %%
df
# Out:
#       Make  Price  Year  Kilometer  Fuel Type  Transmission  Location  Color  \
# 0        7    106    12        680          5             1        56      7
# 1       18     92     9        617          2             1        40     14
# 2        8     19     6        559          5             1        39      8
# 3       29    196    14        288          5             1        41     12
# 4       29    366    13        578          2             1        45      7
# ...    ...    ...   ...        ...        ...           ...       ...    ...
# 2053    18     25     9        639          5             1        20     14
# 2054    17    209    11        692          2             1        66     14
# 2055     8     33     9        663          5             1         1     14
# 2056     6     24     8        608          5             1        67     13
# 2057     1    487    13        508          2             0        12     14
#
# ...

# %%
plt.figure(figsize=(20,35))
for i, col in enumerate (df.columns):
    if df[col].dtype != 'object':
        ax = plt.subplot(17, 2, i+1)
        sns.kdeplot(df[col], ax=ax)
        plt.xlabel(col)
    
plt.show()

# %%
df[::].hist(bins = 20, figsize= (14,14), color= 'skyblue')
# Out:
# array([[<AxesSubplot:title={'center':'Make'}>,
#         <AxesSubplot:title={'center':'Price'}>,
#         <AxesSubplot:title={'center':'Year'}>,
#         <AxesSubplot:title={'center':'Kilometer'}>],
#        [<AxesSubplot:title={'center':'Fuel Type'}>,
#         <AxesSubplot:title={'center':'Transmission'}>,
#         <AxesSubplot:title={'center':'Location'}>,
#         <AxesSubplot:title={'center':'Color'}>],
#        [<AxesSubplot:title={'center':'Owner'}>,
#         <AxesSubplot:title={'center':'Seller Type'}>,
#         <AxesSubplot:title={'center':'Engine'}>,
#         <AxesSubplot:title={'center':'Drivetrain'}>],
#        [<AxesSubplot:title={'center':'Length'}>,
#         <AxesSubplot:title={'center':'Width'}>,
#         <AxesSubplot:title={'center':'Height'}>,
#         <AxesSubplot:title={'center':'Seating Capacity'}>],
#        [<AxesSubplot:title={'center':'Fuel Tank Capacity'}>,
#         <AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>]], dtype=object)

# %%
df.corr()
# Out:
#                         Make     Price      Year  Kilometer  Fuel Type  \
# Make                1.000000 -0.064719  0.024762   0.055249  -0.014610
# Price              -0.064719  1.000000  0.482104  -0.302301  -0.284738
# Year                0.024762  0.482104  1.000000  -0.595160   0.011133
# Kilometer           0.055249 -0.302301 -0.595160   1.000000  -0.285866
# Fuel Type          -0.014610 -0.284738  0.011133  -0.285866   1.000000
# Transmission        0.112661 -0.672261 -0.175110   0.181366   0.058421
# Location            0.036344 -0.148412 -0.066033   0.018537   0.063737
# Color               0.022682 -0.155686 -0.070410   0.086129  -0.027516
# Owner               0.007831  0.015836 -0.229949   0.145551  -0.058278
# Seller Type        -0.044908 -0.073136 -0.040534   0.035320  -0.019608
# Engine              0.131257  0.247544  0.022656  -0.030494  -0.129530
# Drivetrain          0.136862 -0.049951 -0.028189   0.003693  -0.003092
# ...

# %%
plt.figure(figsize=(15,15))
sns.heatmap(df.corr(), annot=True)
plt.show()

# %%
plt.figure(1, figsize=(15,10))
n=0

for x in ['Price','Kilometer','Engine','Length','Width', 'Height', 'Fuel Tank Capacity']:
    n += 1
    plt.subplot(4,2,n)
    plt.subplots_adjust(hspace=0.5, wspace=0.5)
    sns.histplot(df[x], bins= 25)
    plt.title(f'{x}')
plt.show()

# %%
X = df.iloc[:, [12,13,14]].values

# %%
from sklearn.cluster import KMeans
wcss = []
for i in range(1, 11):
    kmeans = KMeans(n_clusters = i, init = 'k-means++', random_state = 42)
    kmeans.fit(X)
    wcss.append(kmeans.inertia_)
plt.plot(range(1, 11), wcss)
plt.title('The Elbow Method')
plt.xlabel('Number of clusters')
plt.ylabel('WCSS')
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1036: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=8.
#   warnings.warn(

# %%
kmeans = KMeans(n_clusters = 4, init = 'k-means++', random_state = 42)
y_kmeans = kmeans.fit_predict(X)

# %%
plt.figure(figsize=(7,7))
plt.scatter(X[y_kmeans == 0, 0], X[y_kmeans == 0, 1], s = 100, c = 'red', label = 'Cluster 1')
plt.scatter(X[y_kmeans == 1, 0], X[y_kmeans == 1, 1], s = 100, c = 'blue', label = 'Cluster 2')
plt.scatter(X[y_kmeans == 2, 0], X[y_kmeans == 2, 1], s = 100, c = 'green', label = 'Cluster 3')
plt.scatter(X[y_kmeans == 3, 0], X[y_kmeans == 3, 1], s = 100, c = 'cyan', label = 'Cluster 4')
plt.scatter(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:, 1], s = 300, c = 'yellow', label = 'Centroids')
plt.title('Clusters of Electric Car')
plt.xlabel('Make')
plt.ylabel('Price')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(15,7))
import scipy.cluster.hierarchy as sch
dendrogram = sch.dendrogram(sch.linkage(X, method = 'ward'))
plt.title('Dendrogram')
plt.show()
